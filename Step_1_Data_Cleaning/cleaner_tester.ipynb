# %%
import pandas as pd
df = pd.read_csv("C:/Users/micha/Pycharm(Local)/LinearRegressionRepo/Data/real_estate_data/train.csv")

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %%
duplicate_free_df = df.drop_duplicates()
df.shape
# Out:
# (1460, 80)

# %%
from data_cleaner import boolean_cleaner
bool_free_df = boolean_cleaner(df)
bool_free_df.shape
# Out:
# (1460, 80)

# %%
from data_cleaner import unnamed_column_cleaner
fully_named_df = unnamed_column_cleaner(df)
fully_named_df.shape
# Out:
# (1460, 80)

# %%
from data_cleaner import outlier_cleaner
outlier_free_df = outlier_cleaner(fully_named_df)
outlier_free_df.shape
# Out:
# column: MSSubClass
# column is numerical, so we do clean for outliers
# dataframe[column]:
#  0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64
# Upper Limit/Lower Limit: 145.0 / -55.0
# Number of outliers in column: 103
# % of column that is outliers: 7.054794520547945 %
# too many outliers, so we are going to drop the column entirely
# dataframe after a column was dropped:
#       MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0          RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1          RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2          RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3          RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4          RL         84.0    14260   Pave   NaN      IR1         Lvl
# ...

# %%
outlier_free_df_columns_list = outlier_free_df.columns.tolist()
fully_named_df_columns_list = fully_named_df.columns.tolist()
# Grabs all the columns that the outlier cleaner function removes
list(set(fully_named_df_columns_list).difference(outlier_free_df_columns_list))
# Out:
# []
