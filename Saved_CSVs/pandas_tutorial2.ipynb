# %%
import pandas as pd
data = pd.read_csv('C:/Users/micha/Pycharm(Local)/LinearRegressionRepo/Saved_CSVs/NBA All.csv')
data
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_10436\2448997980.py:2: DtypeWarning: Columns (2,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:/Users/micha/Pycharm(Local)/LinearRegressionRepo/Saved_CSVs/NBA All.csv')
#            Date  Year Month   Day    Time Day of Week              Home Team  \
# 0        18-Oct  2022   Oct  18.0   7:30p         Tue         Boston Celtics
# 1        18-Oct  2022   Oct  18.0  10:00p         Tue  Golden State Warriors
# 2        19-Oct  2022   Oct  19.0   7:00p         Wed        Detroit Pistons
# 3        19-Oct  2022   Oct  19.0   7:00p         Wed         Indiana Pacers
# 4        19-Oct  2022   Oct  19.0   7:30p         Wed          Atlanta Hawks
# ...         ...   ...   ...   ...     ...         ...                    ...
# 1048570  //2022  2022   NaN   NaN     NaN         NaN                    NaN
# 1048571  //2022  2022   NaN   NaN     NaN         NaN                    NaN
# ...

# %%
data['Date'] = data['Date'].astype(str) + '-' + data['Year'].astype(str)
data.drop('Year', axis=1)
# Out:
#                 Date Month   Day    Time Day of Week              Home Team  \
# 0        18-Oct-2022   Oct  18.0   7:30p         Tue         Boston Celtics
# 1        18-Oct-2022   Oct  18.0  10:00p         Tue  Golden State Warriors
# 2        19-Oct-2022   Oct  19.0   7:00p         Wed        Detroit Pistons
# 3        19-Oct-2022   Oct  19.0   7:00p         Wed         Indiana Pacers
# 4        19-Oct-2022   Oct  19.0   7:30p         Wed          Atlanta Hawks
# ...              ...   ...   ...     ...         ...                    ...
# 1048570  //2022-2022   NaN   NaN     NaN         NaN                    NaN
# 1048571  //2022-2022   NaN   NaN     NaN         NaN                    NaN
# 1048572  //2022-2022   NaN   NaN     NaN         NaN                    NaN
# 1048573  //2022-2022   NaN   NaN     NaN         NaN                    NaN
# 1048574  //2022-2022   NaN   NaN     NaN         NaN                    NaN
#
# ...

# %%
data.to_csv('NBA_New_Data')
